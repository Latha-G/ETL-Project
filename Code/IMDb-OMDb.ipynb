# %% [markdown]
# # Extract Transform Load
# ---

# %%
import pandas as pd
import requests

from config import omdb_key

import json
from pprint import pprint

from splinter import Browser
from bs4 import BeautifulSoup

import re

# %% [markdown]
# ## Scraping IMDB for Top 250 movies
# ___

# %%
# URL to scrape for top 250 IMDb movies

url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

# Read all the tables in the URL

tables = pd.read_html(url)

Raw_df = tables[0]

Raw_df
# Out:
#      Unnamed: 0                                      Rank & Title  \
# 0           NaN              1.  The Shawshank Redemption  (1994)
# 1           NaN                         2.  The Godfather  (1972)
# 2           NaN                3.  The Godfather: Part II  (1974)
# 3           NaN                       4.  The Dark Knight  (2008)
# 4           NaN                          5.  12 Angry Men  (1957)
# ..          ...                                               ...
# 245         NaN  246.  Butch Cassidy and the Sundance Kid  (1969)
# 246         NaN                             247.  Aladdin  (1992)
# 247         NaN                               248.  Akira  (1988)
# 248         NaN                     249.  Throne of Blood  (1957)
# 249         NaN                 250.  Fanny and Alexander  (1982)
#
#      IMDb Rating                         Your Rating  Unnamed: 4
# 0            9.2  12345678910 NOT YET RELEASED  Seen         NaN
# 1            9.1  12345678910 NOT YET RELEASED  Seen         NaN
# 2            9.0  12345678910 NOT YET RELEASED  Seen         NaN
# 3            9.0  12345678910 NOT YET RELEASED  Seen         NaN
# 4            8.9  12345678910 NOT YET RELEASED  Seen         NaN
# ..           ...                                 ...         ...
# 245          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 246          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 247          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 248          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 249          8.0  12345678910 NOT YET RELEASED  Seen         NaN
#
# [250 rows x 5 columns]

# %%
Raw_df = Raw_df.drop(['Unnamed: 0','Your Rating', 'Unnamed: 4'], axis = 1)
Raw_df
# Out:
#                                          Rank & Title  IMDb Rating
# 0                1.  The Shawshank Redemption  (1994)          9.2
# 1                           2.  The Godfather  (1972)          9.1
# 2                  3.  The Godfather: Part II  (1974)          9.0
# 3                         4.  The Dark Knight  (2008)          9.0
# 4                            5.  12 Angry Men  (1957)          8.9
# ..                                                ...          ...
# 245  246.  Butch Cassidy and the Sundance Kid  (1969)          8.0
# 246                             247.  Aladdin  (1992)          8.0
# 247                               248.  Akira  (1988)          8.0
# 248                     249.  Throne of Blood  (1957)          8.0
# 249                 250.  Fanny and Alexander  (1982)          8.0
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Separtae 'Rank & Title' column to Rank, Title and Year columns
# ---

# %%
Imdb_movies = []

for movie in Raw_df['Rank & Title']:
    
    rank = movie.split('.')[0]
    
    title1 = re.split('[.(]', movie)[1]
    title = re.sub("  ", "", title1)
        
    year = re.split('[()]', movie)[1]
  
    Imdb_movies.append({'IMDb Rank': rank,
                        'Movie Title': title,
                        'Year Released': year
                       })
    
Imdb_df = pd.DataFrame(Imdb_movies)
    
Imdb_df['IMDb Rating'] = Raw_df['IMDb Rating'] 
    
Imdb_df
# Out:
#     IMDb Rank                         Movie Title Year Released  IMDb Rating
# 0           1            The Shawshank Redemption          1994          9.2
# 1           2                       The Godfather          1972          9.1
# 2           3              The Godfather: Part II          1974          9.0
# 3           4                     The Dark Knight          2008          9.0
# 4           5                        12 Angry Men          1957          8.9
# ..        ...                                 ...           ...          ...
# 245       246  Butch Cassidy and the Sundance Kid          1969          8.0
# 246       247                             Aladdin          1992          8.0
# 247       248                               Akira          1988          8.0
# 248       249                     Throne of Blood          1957          8.0
# 249       250                 Fanny and Alexander          1982          8.0
#
# [250 rows x 4 columns]

# %% [markdown]
# ## OMDb API
# ---

# %%
# Sample APi request

url = "http://www.omdbapi.com/?apikey=" + omdb_key + "&t="

requests.get(url+"oldboy").json()
# Out:
# {'Title': 'Oldboy',
#  'Year': '2003',
#  'Rated': 'R',
#  'Released': '21 Nov 2003',
#  'Runtime': '120 min',
#  'Genre': 'Action, Drama, Mystery, Thriller',
#  'Director': 'Chan-wook Park',
#  'Writer': 'Garon Tsuchiya (story), Nobuaki Minegishi (comic), Chan-wook Park (character created by: Oldboy,  Vengeance Trilogy), Chan-wook Park (screenplay), Joon-hyung Lim (screenplay), Jo-yun Hwang (screenplay)',
#  'Actors': 'Min-sik Choi, Ji-Tae Yoo, Hye-jeong Kang, Dae-han Ji',
#  'Plot': 'After being kidnapped and imprisoned for fifteen years, Oh Dae-Su is released, only to find that he must find his captor in five days.',
#  'Language': 'Korean',
#  'Country': 'South Korea',
#  'Awards': '39 wins & 18 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI3NTQyMzU5M15BMl5BanBnXkFtZTcwMTM2MjgyMQ@@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#   {'Source': 'Metacritic', 'Value': '77/100'}],
#  'Metascore': '77',
#  'imdbRating': '8.4',
#  'imdbVotes': '488,667',
#  'imdbID': 'tt0364569',
#  'Type': 'movie',
#  'DVD': '23 Aug 2005',
#  'BoxOffice': '$637,778',
#  'Production': 'Tartan Films',
#  'Website': 'N/A',
#  'Response': 'True'}

# %%
base_url = "http://www.omdbapi.com/?apikey=" + omdb_key + "&t="

movie_list = Imdb_df['Movie Title']

ID_list = []
Title_list = []
Rated_list = []
Genre_list = []
Runtime_list = []
Director_list = []
Actors_list = []
Production_list = []
Language_list = []
Awards_list = []
Plot_list = []


for movie in movie_list:
    
    results = requests.get(base_url + movie).json()
    
    try:
        
        ID_list.append(results['imdbID'])
        Title_list.append(results["Title"])
        Rated_list.append(results["Rated"])
        Genre_list.append(results["Genre"])
        Runtime_list.append(results["Runtime"])
        Director_list.append(results["Director"])
        Actors_list.append(results["Actors"])
        Production_list.append(results['Production'])
        Language_list.append(results["Language"])
        Awards_list.append(results["Awards"])
        Plot_list.append(results["Plot"])
        
    except:
        
        print(f'Movie {movie} not found')
        ID_list.append('Nan')
        Title_list.append('movie')
        Rated_list.append('Nan')
        Genre_list.append('Nan')
        Runtime_list.append('Nan')
        Director_list.append('Nan')
        Actors_list.append('Nan')
        Production_list.append('Nan')
        Language_list.append('Nan')
        Awards_list.append('Nan')
        Plot_list.append('Nan')
        pass
# Out:
# Movie Taare Zameen Par not found
# Movie Capharnaüm not found
# Movie Babam ve Oglum not found
# Movie Relatos salvajes not found
# Movie Kis Uykusu not found

# %%
OMDb_df = pd.DataFrame({'IMDb ID' : ID_list,
                        'Movie Title' : Title_list,
                        'Rated' : Rated_list,
                        'Genre': Genre_list,
                        'Director': Director_list,
                        'Actors' : Actors_list,
                        'Production' : Production_list,
                        'Language' : Language_list,
                        'Awards' : Awards_list,
                        'Plot' : Plot_list
                       })

OMDb_df
# Out:
#        IMDb ID                         Movie Title      Rated  \
# 0    tt0111161            The Shawshank Redemption          R
# 1    tt0068646                       The Godfather          R
# 2    tt0071562              The Godfather: Part II          R
# 3    tt0468569                     The Dark Knight      PG-13
# 4    tt0050083                        12 Angry Men   Approved
# ..         ...                                 ...        ...
# 245  tt0064115  Butch Cassidy and the Sundance Kid         PG
# 246  tt0103639                             Aladdin          G
# 247  tt0094625                               Akira          R
# 248  tt0050613                     Throne of Blood  Not Rated
# 249  tt0083922                 Fanny and Alexander          R
#
#                                                  Genre  \
# 0                                                Drama
# 1                                         Crime, Drama
# 2                                         Crime, Drama
# 3                       Action, Crime, Drama, Thriller
# 4                                                Drama
# ..                                                 ...
# 245                   Biography, Crime, Drama, Western
# 246  Animation, Adventure, Comedy, Family, Fantasy,...
# 247                 Animation, Drama, Sci-Fi, Thriller
# 248                                     Drama, History
# 249                                              Drama
#
#                       Director  \
# 0               Frank Darabont
# 1         Francis Ford Coppola
# 2         Francis Ford Coppola
# 3            Christopher Nolan
# 4                 Sidney Lumet
# ..                         ...
# 245            George Roy Hill
# 246  Ron Clements, John Musker
# 247            Katsuhiro Ôtomo
# 248             Akira Kurosawa
# 249             Ingmar Bergman
#
#                                                 Actors  \
# 0    Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1    Marlon Brando, Al Pacino, James Caan, Richard ...
# 2    Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3    Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4    Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# ..                                                 ...
# 245  Paul Newman, Robert Redford, Katharine Ross, S...
# 246  Scott Weinger, Robin Williams, Linda Larkin, J...
# 247  Mitsuo Iwata, Nozomu Sasaki, Mami Koyama, Tess...
# 248  Toshirô Mifune, Isuzu Yamada, Takashi Shimura,...
# 249  Kristina Adolphson, Börje Ahlstedt, Pernilla A...
#
#                           Production  \
# 0                  Columbia Pictures
# 1                 Paramount Pictures
# 2                 Paramount Pictures
# 3    Warner Bros. Pictures/Legendary
# 4               Criterion Collection
# ..                               ...
# 245                 20th Century Fox
# 246             Walt Disney Pictures
# 247              Streamline Pictures
# 248         Media Home Entertainment
# 249     Embassy Pictures Corporation
#
#                                        Language  \
# 0                                       English
# 1                       English, Italian, Latin
# 2    English, Italian, Spanish, Latin, Sicilian
# 3                             English, Mandarin
# 4                                       English
# ..                                          ...
# 245                            English, Spanish
# 246                                     English
# 247                                    Japanese
# 248                                    Japanese
# 249   Swedish, German, Yiddish, English, French
#
#                                                 Awards  \
# 0    Nominated for 7 Oscars. Another 21 wins & 35 n...
# 1      Won 3 Oscars. Another 26 wins & 30 nominations.
# 2      Won 6 Oscars. Another 11 wins & 20 nominations.
# 3    Won 2 Oscars. Another 153 wins & 159 nominations.
# 4    Nominated for 3 Oscars. Another 16 wins & 9 no...
# ..                                                 ...
# 245    Won 4 Oscars. Another 17 wins & 14 nominations.
# 246    Won 2 Oscars. Another 31 wins & 22 nominations.
# 247                                             1 win.
# 248                             3 wins & 1 nomination.
# 249    Won 4 Oscars. Another 21 wins & 11 nominations.
#
#                                                   Plot
# 0    Two imprisoned men bond over a number of years...
# 1    The aging patriarch of an organized crime dyna...
# 2    The early life and career of Vito Corleone in ...
# 3    When the menace known as the Joker wreaks havo...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 245  Wyoming, early 1900s. Butch Cassidy and The Su...
# 246  A kindhearted street urchin and a power-hungry...
# 247  A secret military project endangers Neo-Tokyo ...
# 248  A war-hardened general, egged on by his ambiti...
# 249  Two young Swedish children experience the many...
#
# [250 rows x 10 columns]

# %% [markdown]
# ## Merging IMDb_df and OMDb_df
# ---

# %%
Top_Movies_df = Imdb_df.merge(OMDb_df, how = 'inner', on = 'Movie Title')

Top_Movies_df.set_index('IMDb Rank', inplace = True)

# Moving 'IMDb ID' column to the front

first_col = Top_Movies_df.pop("IMDb ID")

Top_Movies_df.insert(0, "IMDb ID", first_col)

Top_Movies_df
# Out:
#              IMDb ID                         Movie Title Year Released  \
# IMDb Rank
# 1          tt0111161            The Shawshank Redemption          1994
# 2          tt0068646                       The Godfather          1972
# 3          tt0071562              The Godfather: Part II          1974
# 4          tt0468569                     The Dark Knight          2008
# 5          tt0050083                        12 Angry Men          1957
# ...              ...                                 ...           ...
# 246        tt0064115  Butch Cassidy and the Sundance Kid          1969
# 247        tt0103639                             Aladdin          1992
# 248        tt0094625                               Akira          1988
# 249        tt0050613                     Throne of Blood          1957
# 250        tt0083922                 Fanny and Alexander          1982
#
#            IMDb Rating      Rated  \
# IMDb Rank
# 1                  9.2          R
# 2                  9.1          R
# 3                  9.0          R
# 4                  9.0      PG-13
# 5                  8.9   Approved
# ...                ...        ...
# 246                8.0         PG
# 247                8.0          G
# 248                8.0          R
# 249                8.0  Not Rated
# 250                8.0          R
#
#                                                        Genre  \
# IMDb Rank
# 1                                                      Drama
# 2                                               Crime, Drama
# 3                                               Crime, Drama
# 4                             Action, Crime, Drama, Thriller
# 5                                                      Drama
# ...                                                      ...
# 246                         Biography, Crime, Drama, Western
# 247        Animation, Adventure, Comedy, Family, Fantasy,...
# 248                       Animation, Drama, Sci-Fi, Thriller
# 249                                           Drama, History
# 250                                                    Drama
#
#                             Director  \
# IMDb Rank
# 1                     Frank Darabont
# 2               Francis Ford Coppola
# 3               Francis Ford Coppola
# 4                  Christopher Nolan
# 5                       Sidney Lumet
# ...                              ...
# 246                  George Roy Hill
# 247        Ron Clements, John Musker
# 248                  Katsuhiro Ôtomo
# 249                   Akira Kurosawa
# 250                   Ingmar Bergman
#
#                                                       Actors  \
# IMDb Rank
# 1          Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 2          Marlon Brando, Al Pacino, James Caan, Richard ...
# 3          Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 4          Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 5          Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# ...                                                      ...
# 246        Paul Newman, Robert Redford, Katharine Ross, S...
# 247        Scott Weinger, Robin Williams, Linda Larkin, J...
# 248        Mitsuo Iwata, Nozomu Sasaki, Mami Koyama, Tess...
# 249        Toshirô Mifune, Isuzu Yamada, Takashi Shimura,...
# 250        Kristina Adolphson, Börje Ahlstedt, Pernilla A...
#
#                                 Production  \
# IMDb Rank
# 1                        Columbia Pictures
# 2                       Paramount Pictures
# 3                       Paramount Pictures
# 4          Warner Bros. Pictures/Legendary
# 5                     Criterion Collection
# ...                                    ...
# 246                       20th Century Fox
# 247                   Walt Disney Pictures
# 248                    Streamline Pictures
# 249               Media Home Entertainment
# 250           Embassy Pictures Corporation
#
#                                              Language  \
# IMDb Rank
# 1                                             English
# 2                             English, Italian, Latin
# 3          English, Italian, Spanish, Latin, Sicilian
# 4                                   English, Mandarin
# 5                                             English
# ...                                               ...
# 246                                  English, Spanish
# 247                                           English
# 248                                          Japanese
# 249                                          Japanese
# 250         Swedish, German, Yiddish, English, French
#
#                                                       Awards  \
# IMDb Rank
# 1          Nominated for 7 Oscars. Another 21 wins & 35 n...
# 2            Won 3 Oscars. Another 26 wins & 30 nominations.
# 3            Won 6 Oscars. Another 11 wins & 20 nominations.
# 4          Won 2 Oscars. Another 153 wins & 159 nominations.
# 5          Nominated for 3 Oscars. Another 16 wins & 9 no...
# ...                                                      ...
# 246          Won 4 Oscars. Another 17 wins & 14 nominations.
# 247          Won 2 Oscars. Another 31 wins & 22 nominations.
# 248                                                   1 win.
# 249                                   3 wins & 1 nomination.
# 250          Won 4 Oscars. Another 21 wins & 11 nominations.
#
#                                                         Plot
# IMDb Rank
# 1          Two imprisoned men bond over a number of years...
# 2          The aging patriarch of an organized crime dyna...
# 3          The early life and career of Vito Corleone in ...
# 4          When the menace known as the Joker wreaks havo...
# 5          A jury holdout attempts to prevent a miscarria...
# ...                                                      ...
# 246        Wyoming, early 1900s. Butch Cassidy and The Su...
# 247        A kindhearted street urchin and a power-hungry...
# 248        A secret military project endangers Neo-Tokyo ...
# 249        A war-hardened general, egged on by his ambiti...
# 250        Two young Swedish children experience the many...
#
# [239 rows x 12 columns]

# %%
Top_Movies_df.to_csv('../Output/Complete_IMDbTopMovies.csv')

# %%
import os
print(os.getcwd())
# Out:
# /Users/swarnaguntaka/Desktop/ETL-Project/Code
