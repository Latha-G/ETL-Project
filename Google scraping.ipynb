# %% [markdown]
# # Google Scraping
# ---

# %%
import pandas as pd
import requests

from config import omdb_key

import json
from pprint import pprint

from splinter import Browser
from bs4 import BeautifulSoup

import re
import time

# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Scraping IMDB for Top 250 movies
# ___

# %%
# URL to scrape for top 250 IMDb movies

url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

# Read all the tables in the URL

tables = pd.read_html(url)

Raw_df = tables[0]

Raw_df
# Out:
#      Unnamed: 0                                      Rank & Title  \
# 0           NaN              1.  The Shawshank Redemption  (1994)
# 1           NaN                         2.  The Godfather  (1972)
# 2           NaN                3.  The Godfather: Part II  (1974)
# 3           NaN                       4.  The Dark Knight  (2008)
# 4           NaN                          5.  12 Angry Men  (1957)
# ..          ...                                               ...
# 245         NaN  246.  Butch Cassidy and the Sundance Kid  (1969)
# 246         NaN                             247.  Aladdin  (1992)
# 247         NaN                               248.  Akira  (1988)
# 248         NaN                     249.  Throne of Blood  (1957)
# 249         NaN                 250.  Fanny and Alexander  (1982)
#
#      IMDb Rating                         Your Rating  Unnamed: 4
# 0            9.2  12345678910 NOT YET RELEASED  Seen         NaN
# 1            9.1  12345678910 NOT YET RELEASED  Seen         NaN
# 2            9.0  12345678910 NOT YET RELEASED  Seen         NaN
# 3            9.0  12345678910 NOT YET RELEASED  Seen         NaN
# 4            8.9  12345678910 NOT YET RELEASED  Seen         NaN
# ..           ...                                 ...         ...
# 245          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 246          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 247          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 248          8.0  12345678910 NOT YET RELEASED  Seen         NaN
# 249          8.0  12345678910 NOT YET RELEASED  Seen         NaN
#
# [250 rows x 5 columns]

# %%
Raw_df = Raw_df.drop(['Unnamed: 0','Your Rating', 'Unnamed: 4'], axis = 1)
Raw_df
# Out:
#                                          Rank & Title  IMDb Rating
# 0                1.  The Shawshank Redemption  (1994)          9.2
# 1                           2.  The Godfather  (1972)          9.1
# 2                  3.  The Godfather: Part II  (1974)          9.0
# 3                         4.  The Dark Knight  (2008)          9.0
# 4                            5.  12 Angry Men  (1957)          8.9
# ..                                                ...          ...
# 245  246.  Butch Cassidy and the Sundance Kid  (1969)          8.0
# 246                             247.  Aladdin  (1992)          8.0
# 247                               248.  Akira  (1988)          8.0
# 248                     249.  Throne of Blood  (1957)          8.0
# 249                 250.  Fanny and Alexander  (1982)          8.0
#
# [250 rows x 2 columns]

# %% [markdown]
# ### Separate 'Rank & Title' column to Rank, Title and Year columns
# ---

# %%
Imdb_movies = []

for movie in Raw_df['Rank & Title']:
    
    rank = movie.split('.')[0]
    
    title1 = re.split('[.(]', movie)[1]
    title = re.sub("  ", "", title1)
        
    year = re.split('[()]', movie)[1]
  
    Imdb_movies.append({'IMDb Rank': rank,
                        'Movie Title': title,
                        'Year Released': year
                       })
    
Imdb_df = pd.DataFrame(Imdb_movies)
    
Imdb_df['IMDb Rating'] = Raw_df['IMDb Rating'] 
    
Imdb_df
# Out:
#     IMDb Rank                         Movie Title Year Released  IMDb Rating
# 0           1            The Shawshank Redemption          1994          9.2
# 1           2                       The Godfather          1972          9.1
# 2           3              The Godfather: Part II          1974          9.0
# 3           4                     The Dark Knight          2008          9.0
# 4           5                        12 Angry Men          1957          8.9
# ..        ...                                 ...           ...          ...
# 245       246  Butch Cassidy and the Sundance Kid          1969          8.0
# 246       247                             Aladdin          1992          8.0
# 247       248                               Akira          1988          8.0
# 248       249                     Throne of Blood          1957          8.0
# 249       250                 Fanny and Alexander          1982          8.0
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Building the URL to scrape Google
# ---

# %%
movies = Imdb_df['Movie Title']
movies = movies.str.replace(',', '', n = -1, case=None, regex=True)
movies = movies.str.replace("'",'', n = -1, case=None, regex=True)
movies = movies.str.replace(":",'', n = -1, case=None, regex=True)
movies = movies.str.replace(".",'', n = -1, case=None, regex=True)

movies
# Out:
# 0                The Shawshank Redemption
# 1                           The Godfather
# 2                   The Godfather Part II
# 3                         The Dark Knight
# 4                            12 Angry Men
#                       ...
# 245    Butch Cassidy and the Sundance Kid
# 246                               Aladdin
# 247                                 Akira
# 248                       Throne of Blood
# 249                   Fanny and Alexander
# Name: Movie Title, Length: 250, dtype: object

# %%
base_url = 'https://www.google.com/search?&q='

movie_list = movies.str.lower().str.replace(' ', '+', n = -1, case=None, regex=True)

query_url=[]

for movie in movie_list:

    query_url.append(f'{base_url}{movie}+watch+movie')
    print(query_url)
# Out:
# ['https://www.google.com/search?&q=the+shawshank+redemption+watch+movie', 'https://www.google.com/search?&q=the+godfather+watch+movie', 'https://www.google.com/search?&q=the+godfather+part+ii+watch+movie', 'https://www.google.com/search?&q=the+dark+knight+watch+movie', 'https://www.google.com/search?&q=12+angry+men+watch+movie', 'https://www.google.com/search?&q=schindlers+list+watch+movie', 'https://www.google.com/search?&q=the+lord+of+the+rings+the+return+of+the+king+watch+movie', 'https://www.google.com/search?&q=pulp+fiction+watch+movie', 'https://www.google.com/search?&q=the+good+the+bad+and+the+ugly+watch+movie', 'https://www.google.com/search?&q=the+lord+of+the+rings+the+fellowship+of+the+ring+watch+movie', 'https://www.google.com/search?&q=fight+club+watch+movie', 'https://www.google.com/search?&q=forrest+gump+watch+movie', 'https://www.google.com/search?&q=inception+watch+movie', 'https://www.google.com/search?&q=star+wars+episode+v+-+the+empire+strikes+back+watch+movie', 'https://www.google.com/search?&q=the+lord+of+the+rings+the+two+towers+watch+movie', 'https://www.google.com/search?&q=the+matrix+watch+movie', 'https://www.google.com/search?&q=goodfellas+watch+movie', 'https://www.google.com/search?&q=one+flew+over+the+cuckoos+nest+watch+movie', 'https://www.google.com/search?&q=seven+samurai+watch+movie', 'https://www.google.com/search?&q=se7en+watch+movie', 'https://www.google.com/search?&q=life+is+beautiful+watch+movie', 'https://www.google.com/search?&q=city+of+god+watch+movie', 'https://www.google.com/search?&q=the+silence+of+the+lambs+watch+movie', 'https://www.google.com/search?&q=its+a+wonderful+life+watch+movie', 'https://www.google.com/search?&q=star+wars+episode+iv+-+a+new+hope+watch+movie', 'https://www.google.com/search?&q=parasite+watch+movie', 'https://www.google.com/search?&q=saving+private+ryan+watch+movie', 'https://www.google.com/search?&q=spirited+away+watch+movie', 'https://www.google.com/search?&q=the+green+mile+watch+movie', 'https://www.google.com/search?&q=interstellar+watch+movie', 'https://www.google.com/search?&q=léon+the+professional+watch+movie', 'https://www.google.com/search?&q=the+usual+suspects+watch+movie', 'https://www.google.com/search?&q=harakiri+watch+movie', 'https://www.google.com/search?&q=the+lion+king+watch+movie', 'https://www.google.com/search?&q=american+history+x+watch+movie', 'https://www.google.com/search?&q=the+pianist+watch+movie', 'https://www.google.com/search?&q=terminator+2+judgment+day+watch+movie', 'https://www.google.com/search?&q=back+to+the+future+watch+movie', 'https://www.google.com/search?&q=modern+times+watch+movie', 'https://www.google.com/search?&q=psycho+watch+movie', 'https://www.google.com/search?&q=gladiator+watch+movie', 'https://www.google.com/search?&q=city+lights+watch+movie', 'https://www.google.com/search?&q=the+departed+watch+movie', 'https://www.google.com/search?&q=the+intouchables+watch+movie', 'https://www.google.com/search?&q=whiplash+watch+movie', 'https://www.google.com/search?&q=the+prestige+watch+movie', 'https://www.google.com/search?&q=once+upon+a+time+in+the+west+watch+movie', 'https://www.google.com/search?&q=grave+of+the+fireflies+watch+movie', 'https://www.google.com/search?&q=casablanca+watch+movie', 'https://www.google.com/search?&q=cinema+paradiso+watch+movie', 'https://www.google.com/search?&q=rear+window+watch+movie', 'https://www.google.com/search?&q=joker+watch+movie', 'https://www.google.com/search?&q=alien+watch+movie', 'https://www.google.com/search?&q=apocalypse+now+watch+movie', 'https://www.google.com/search?&q=memento+watch+movie', 'https://www.google.com/search?&q=raiders+of+the+lost+ark+watch+movie', 'https://www.google.com/search?&q=the+great+dictator+watch+movie', 'https://www.google.com/search?&q=the+lives+of+others+watch+movie', 'https://www.google.com/search?&q=django+unchained+watch+movie', 'https://www.google.com/search?&q=paths+of+glory+watch+movie', 'https://www.google.com/search?&q=the+shining+watc ...

# %%
google_query_url_df = pd.DataFrame({'IMDb Rank': Imdb_df['IMDb Rank'],
                                    'Movie Title': Imdb_df['Movie Title'],
                                    'Google Query URL' : query_url
                                   })

google_query_url_df = google_query_url_df.set_index(['IMDb Rank'])

google_query_url_df
# Out:
#                                   Movie Title  \
# IMDb Rank
# 1                    The Shawshank Redemption
# 2                               The Godfather
# 3                      The Godfather: Part II
# 4                             The Dark Knight
# 5                                12 Angry Men
# ...                                       ...
# 246        Butch Cassidy and the Sundance Kid
# 247                                   Aladdin
# 248                                     Akira
# 249                           Throne of Blood
# 250                       Fanny and Alexander
#
#                                             Google Query URL
# IMDb Rank
# 1          https://www.google.com/search?&q=the+shawshank...
# 2          https://www.google.com/search?&q=the+godfather...
# 3          https://www.google.com/search?&q=the+godfather...
# 4          https://www.google.com/search?&q=the+dark+knig...
# 5          https://www.google.com/search?&q=12+angry+men+...
# ...                                                      ...
# 246        https://www.google.com/search?&q=butch+cassidy...
# 247        https://www.google.com/search?&q=aladdin+watch...
# 248        https://www.google.com/search?&q=akira+watch+m...
# 249        https://www.google.com/search?&q=throne+of+blo...
# 250        https://www.google.com/search?&q=fanny+and+ale...
#
# [250 rows x 2 columns]

# %%
google_query_url_df.to_csv('Output/Google_Query_Url.csv')

# %% [markdown]
# #### Sample
# ---

# %%
#sample

sample = 'Inception'

base_url = 'https://www.google.com/search?&q='

query_url = (f'{base_url}{sample}+watch+movie')

browser.visit(query_url)

time.sleep(5)

soup = BeautifulSoup(browser.html, 'lxml')

streaming = []
title = []
price = []

results1 = soup.find_all('div', class_ = 'i3LlFf')

for result in results1:
    streaming.append(result.text)
    title.append(sample.capitalize())
    
results2 = soup.find_all('div', class_ = 'V8xno')

for result in results2:
    price.append(result.text)

Sample_Streaming_df = pd.DataFrame({'Title': title,
                                    'Streaming On' : streaming,
                                    'Price' : price
                                   })

Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("$","", case = True, regex=True)
Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("From ","", case = True, regex=True)

Sample_Streaming_df
# Out:
#        Title             Streaming On         Price
# 0  Inception                  YouTube          3.99
# 1  Inception  Google Play Movies & TV          3.99
# 2  Inception                   iTunes          3.99
# 3  Inception                     Vudu          3.99
# 4  Inception       Amazon Prime Video          3.99
# 5  Inception                  Netflix  Subscription

# %%
Sample_Streaming_df.to_csv('Output/Sample_Google_Scraping.csv')

# %% [markdown]
# ## Scraping Google for few movies at a time
# ---

# %%
Streaming = []
Title = []
Price = []

count = 0

movies = google_query_url_df['Movie Title']

query_urls = google_query_url_df['Google Query URL']

base_url = 'https://www.google.com/search?&q='

# %%
for i in range(10):
    
    query_url = (f'{base_url}{movies[count]}+watch+movie')

    browser.visit(query_url)

    time.sleep(3)

    soup = BeautifulSoup(browser.html, 'lxml')

    results1 = soup.find_all('div', class_ = 'i3LlFf')

    for result in results1:
        try:
            Streaming.append(result.text)
            Title.append(movies[count].capitalize())
        except:
            Streaming.append('Nan')
            Title.append('Nan')

    results2 = soup.find_all('div', class_ = 'V8xno')

    for result in results2:
        try:
            Price.append(result.text)
        except:
            Price.append('Nan')
            
    count = count + 1

print(f'{Title}, {Streaming}, {Price}')
# Out:
# ['The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The shawshank redemption', 'The godfather', 'The godfather', 'The godfather', 'The godfather', 'The godfather: part ii', 'The godfather: part ii', 'The godfather: part ii', 'The godfather: part ii', 'The dark knight', 'The dark knight', 'The dark knight', 'The dark knight', 'The dark knight', 'The dark knight', '12 angry men', '12 angry men', '12 angry men', '12 angry men', '12 angry men', "Schindler's list", "Schindler's list", "Schindler's list", "Schindler's list", "Schindler's list", "Schindler's list", 'The lord of the rings: the return of the king', 'The lord of the rings: the return of the king', 'The lord of the rings: the return of the king', 'The lord of the rings: the return of the king', 'The lord of the rings: the return of the king', 'Pulp fiction', 'Pulp fiction', 'Pulp fiction', 'Pulp fiction', 'Pulp fiction', 'Pulp fiction', 'The good, the bad and the ugly', 'The good, the bad and the ugly', 'The good, the bad and the ugly', 'The good, the bad and the ugly', 'The good, the bad and the ugly', 'The good, the bad and the ugly', 'The lord of the rings: the fellowship of the ring', 'The lord of the rings: the fellowship of the ring', 'The lord of the rings: the fellowship of the ring', 'The lord of the rings: the fellowship of the ring', 'Fight club', 'Fight club', 'Fight club', 'Fight club', 'Fight club', 'Fight club', 'Forrest gump', 'Forrest gump', 'Forrest gump', 'Forrest gump', 'Forrest gump', 'Forrest gump', 'Inception', 'Inception', 'Inception', 'Inception', 'Inception', 'Inception', 'Star wars: episode v - the empire strikes back', 'Star wars: episode v - the empire strikes back', 'Star wars: episode v - the empire strikes back', 'Star wars: episode v - the empire strikes back', 'Star wars: episode v - the empire strikes back', 'Star wars: episode v - the empire strikes back', 'The lord of the rings: the two towers', 'The lord of the rings: the two towers', 'The lord of the rings: the two towers', 'The lord of the rings: the two towers', 'The matrix', 'The matrix', 'The matrix', 'The matrix', 'The matrix', 'The matrix', 'Goodfellas', 'Goodfellas', 'Goodfellas', 'Goodfellas', 'Goodfellas', 'Goodfellas', "One flew over the cuckoo's nest", "One flew over the cuckoo's nest", "One flew over the cuckoo's nest", "One flew over the cuckoo's nest", "One flew over the cuckoo's nest", 'Seven samurai', 'Seven samurai', 'Seven samurai', 'Seven samurai', 'Seven samurai', 'Se7en', 'Se7en', 'Se7en', 'Se7en', 'Se7en', 'Se7en', 'Life is beautiful', 'Life is beautiful', 'Life is beautiful', 'Life is beautiful', 'Life is beautiful', 'Life is beautiful', 'City of god', 'City of god', 'City of god', 'City of god', 'City of god', 'The silence of the lambs', 'The silence of the lambs', 'The silence of the lambs', 'The silence of the lambs', 'The silence of the lambs', 'The silence of the lambs', "It's a wonderful life", "It's a wonderful life", "It's a wonderful life", "It's a wonderful life", "It's a wonderful life", 'Star wars: episode iv - a new hope', 'Star wars: episode iv - a new hope', 'Star wars: episode iv - a new hope', 'Star wars: episode iv - a new hope', 'Star wars: episode iv - a new hope', 'Star wars: episode iv - a n ...

# %%
print(f'Scraped {count} movies so far')
# Out:
# Scraped 164 movies so far

# %%
Streaming_df = pd.DataFrame({'Title': Title,
                             'Streaming On' : Streaming,
                             'Price' : Price
                            })

Streaming_df['Price'] = Streaming_df['Price'].str.replace("$","", case = True, regex=True)
Streaming_df['Price'] = Streaming_df['Price'].str.replace("From ","", case = True, regex=True)

Streaming_df.head(40)
# Out:
#                         Title             Streaming On         Price
# 0    The shawshank redemption                  YouTube          3.99
# 1    The shawshank redemption                   iTunes          3.99
# 2    The shawshank redemption  Google Play Movies & TV          3.99
# 3    The shawshank redemption                     Vudu          3.99
# 4    The shawshank redemption       Amazon Prime Video          3.99
# ..                        ...                      ...           ...
# 818                 The thing                   iTunes          3.99
# 819                 The thing  Google Play Movies & TV          3.99
# 820                 The thing                     Vudu          3.99
# 821                 The thing       Amazon Prime Video          3.99
# 822                 The thing                     Hulu  Subscription
#
# [823 rows x 3 columns]

# %%
Streaming_df.to_csv('Output/Complete_Google_Scraping.csv')

# %%
import os
os.getcwd()
# Out:
# '/Users/swarnaguntaka/Desktop/ETL-Project'
