# %% [markdown]
# # Google Scraping
# ---

# %%
import pandas as pd
import requests

from config import omdb_key

import json
from pprint import pprint

from splinter import Browser
from bs4 import BeautifulSoup

import re
import time

# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Scraping IMDB for Top 250 movies
# ___

# %%
# URL to scrape for top 250 IMDb movies

url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

# Read all the tables in the URL

tables = pd.read_html(url)

Raw_df = tables[0]

Raw_df.head()
# Out:
#    Unnamed: 0                          Rank & Title  IMDb Rating  \
# 0         NaN  1.  The Shawshank Redemption  (1994)          9.2
# 1         NaN             2.  The Godfather  (1972)          9.1
# 2         NaN    3.  The Godfather: Part II  (1974)          9.0
# 3         NaN           4.  The Dark Knight  (2008)          9.0
# 4         NaN              5.  12 Angry Men  (1957)          8.9
#
#                           Your Rating  Unnamed: 4
# 0  12345678910 NOT YET RELEASED  Seen         NaN
# 1  12345678910 NOT YET RELEASED  Seen         NaN
# 2  12345678910 NOT YET RELEASED  Seen         NaN
# 3  12345678910 NOT YET RELEASED  Seen         NaN
# 4  12345678910 NOT YET RELEASED  Seen         NaN

# %%
Raw_df = Raw_df.drop(['Unnamed: 0','Your Rating', 'Unnamed: 4'], axis = 1)
Raw_df.head(10)
# Out:
#                                         Rank & Title  IMDb Rating
# 0               1.  The Shawshank Redemption  (1994)          9.2
# 1                          2.  The Godfather  (1972)          9.1
# 2                 3.  The Godfather: Part II  (1974)          9.0
# 3                        4.  The Dark Knight  (2008)          9.0
# 4                           5.  12 Angry Men  (1957)          8.9
# 5                       6.  Schindler's List  (1993)          8.9
# 6  7.  The Lord of the Rings: The Return of the K...          8.9
# 7                           8.  Pulp Fiction  (1994)          8.8
# 8         9.  The Good, the Bad and the Ugly  (1966)          8.8
# 9  10.  The Lord of the Rings: The Fellowship of ...          8.8

# %% [markdown]
# ### Separate 'Rank & Title' column to Rank, Title and Year columns
# ---

# %%
Imdb_movies = []

for movie in Raw_df['Rank & Title']:
    
    rank = movie.split('.')[0]
    
    title1 = re.split('[.(]', movie)[1]
    title = re.sub("  ", "", title1)
        
    year = re.split('[()]', movie)[1]
  
    Imdb_movies.append({'IMDb Rank': rank,
                        'Movie Title': title,
                        'Year Released': year
                       })
    
Imdb_df = pd.DataFrame(Imdb_movies)
    
Imdb_df['IMDb Rating'] = Raw_df['IMDb Rating'] 
    
Imdb_df.head(10)
# Out:
#   IMDb Rank                                        Movie Title Year Released  \
# 0         1                           The Shawshank Redemption          1994
# 1         2                                      The Godfather          1972
# 2         3                             The Godfather: Part II          1974
# 3         4                                    The Dark Knight          2008
# 4         5                                       12 Angry Men          1957
# 5         6                                   Schindler's List          1993
# 6         7      The Lord of the Rings: The Return of the King          2003
# 7         8                                       Pulp Fiction          1994
# 8         9                     The Good, the Bad and the Ugly          1966
# 9        10  The Lord of the Rings: The Fellowship of the Ring          2001
#
#    IMDb Rating
# 0          9.2
# 1          9.1
# 2          9.0
# 3          9.0
# 4          8.9
# 5          8.9
# 6          8.9
# 7          8.8
# 8          8.8
# 9          8.8

# %% [markdown]
# ### Building the URL to scrape Google
# ---

# %%
movies = Imdb_df['Movie Title']
movies = movies.str.replace(',', '', n = -1, case=None, regex=True)
movies = movies.str.replace("'",'', n = -1, case=None, regex=True)
movies = movies.str.replace(":",'', n = -1, case=None, regex=True)
movies = movies.str.replace(".",'', n = -1, case=None, regex=True)

# %%
base_url = 'https://www.google.com/search?&q='

movie_list = movies.str.lower().str.replace(' ', '+', n = -1, case=None, regex=True)

query_url=[]

for movie in movie_list:
    query_url.append(f'{base_url}{movie}+watch+movie')

# %%
google_query_url_df = pd.DataFrame({'IMDb Rank': Imdb_df['IMDb Rank'],
                                    'Movie Title': Imdb_df['Movie Title'],
                                    'Google Query URL' : query_url
                                   })

google_query_url_df = google_query_url_df.set_index(['IMDb Rank'])

google_query_url_df.head(20)
# Out:
#                                                  Movie Title  \
# IMDb Rank
# 1                                   The Shawshank Redemption
# 2                                              The Godfather
# 3                                     The Godfather: Part II
# 4                                            The Dark Knight
# 5                                               12 Angry Men
# 6                                           Schindler's List
# 7              The Lord of the Rings: The Return of the King
# 8                                               Pulp Fiction
# 9                             The Good, the Bad and the Ugly
# 10         The Lord of the Rings: The Fellowship of the Ring
# 11                                                Fight Club
# 12                                              Forrest Gump
# 13                                                 Inception
# 14            Star Wars: Episode V - The Empire Strikes Back
# 15                     The Lord of the Rings: The Two Towers
# 16                                                The Matrix
# 17                                                Goodfellas
# 18                           One Flew Over the Cuckoo's Nest
# 19                                             Seven Samurai
# 20                                                     Se7en
#
#                                             Google Query URL
# IMDb Rank
# 1          https://www.google.com/search?&q=the+shawshank...
# 2          https://www.google.com/search?&q=the+godfather...
# 3          https://www.google.com/search?&q=the+godfather...
# 4          https://www.google.com/search?&q=the+dark+knig...
# 5          https://www.google.com/search?&q=12+angry+men+...
# 6          https://www.google.com/search?&q=schindler's+l...
# 7          https://www.google.com/search?&q=the+lord+of+t...
# 8          https://www.google.com/search?&q=pulp+fiction+...
# 9          https://www.google.com/search?&q=the+good,+the...
# 10         https://www.google.com/search?&q=the+lord+of+t...
# 11         https://www.google.com/search?&q=fight+club+wa...
# 12         https://www.google.com/search?&q=forrest+gump+...
# 13         https://www.google.com/search?&q=inception+wat...
# 14         https://www.google.com/search?&q=star+wars:+ep...
# 15         https://www.google.com/search?&q=the+lord+of+t...
# 16         https://www.google.com/search?&q=the+matrix+wa...
# 17         https://www.google.com/search?&q=goodfellas+wa...
# 18         https://www.google.com/search?&q=one+flew+over...
# 19         https://www.google.com/search?&q=seven+samurai...
# 20         https://www.google.com/search?&q=se7en+watch+m...

# %%
google_query_url_df.to_csv('Output/Google_Query_Url.csv')

# %% [markdown]
# #### Sample
# ---

# %%
#sample

sample = 'Inception'

base_url = 'https://www.google.com/search?&q='

query_url = (f'{base_url}{sample}+watch+movie')

browser.visit(query_url)

time.sleep(5)

soup = BeautifulSoup(browser.html, 'lxml')

streaming = []
title = []
price = []

results1 = soup.find_all('div', class_ = 'i3LlFf')

for result in results1:
    streaming.append(result.text)
    title.append(sample.capitalize())
    
results2 = soup.find_all('div', class_ = 'V8xno')

for result in results2:
    price.append(result.text)

Sample_Streaming_df = pd.DataFrame({'Title': title,
                                    'Streaming On' : streaming,
                                    'Price' : price
                                   })

Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("$","", case = True, regex=True)
Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("From ","", case = True, regex=True)

Sample_Streaming_df
# Out:
#        Title             Streaming On         Price
# 0  Inception                  YouTube          3.99
# 1  Inception  Google Play Movies & TV          3.99
# 2  Inception                   iTunes          3.99
# 3  Inception                     Vudu          3.99
# 4  Inception       Amazon Prime Video          3.99
# 5  Inception                  Netflix  Subscription

# %%
Sample_Streaming_df.to_csv('Output/Sample_Google_Scraping.csv')

# %% [markdown]
# ## Scraping Google for few movies at a time
# ---

# %%
Streaming = []
Title = []
Price = []

count = 0

movies = google_query_url_df['Movie Title']

query_urls = google_query_url_df['Google Query URL']

base_url = 'https://www.google.com/search?&q='

# %%
for i in range(8):
    
    query_url = (f'{base_url}{movies[count]}+watch+movie')

    browser.visit(query_url)

    time.sleep(3)

    soup = BeautifulSoup(browser.html, 'lxml')

    results1 = soup.find_all('div', class_ = 'i3LlFf')

    for result in results1:
        try:
            Streaming.append(result.text)
            Title.append(movies[count].capitalize())
        except:
            Streaming.append('Nan')
            Title.append('Nan')

    results2 = soup.find_all('div', class_ = 'V8xno')

    for result in results2:
        try:
            Price.append(result.text)
        except:
            Price.append('Nan')
            
    count = count + 1

print(f'{Title}, {Streaming}, {Price}')

# %%
Streaming_df = pd.DataFrame({'Title': Title,
                             'Streaming On' : Streaming,
                             'Price' : Price
                            })

Streaming_df['Price'] = Streaming_df['Price'].str.replace("$","", case = True, regex=True)
Streaming_df['Price'] = Streaming_df['Price'].str.replace("From ","", case = True, regex=True)
Streaming_df['Title'] = Streaming_df['Title'].str.title()

# %%
Streaming_df.head(35)

# %%
# Removing the extra rows

Streaming_df_1 = Streaming_df.iloc[24:]
Streaming_df_1 = Streaming_df_1.reset_index()
Streaming_df_1 = Streaming_df_1.drop(['index'],axis = 1)
Streaming_df_1
# Out:
#                         Title             Streaming On         Price
# 0    The Shawshank Redemption                  YouTube          3.99
# 1    The Shawshank Redemption                   iTunes          3.99
# 2    The Shawshank Redemption  Google Play Movies & TV          3.99
# 3    The Shawshank Redemption                     Vudu          3.99
# 4    The Shawshank Redemption       Amazon Prime Video          3.99
# ..                        ...                      ...           ...
# 794                 The Thing                   iTunes          3.99
# 795                 The Thing  Google Play Movies & TV          3.99
# 796                 The Thing                     Vudu          3.99
# 797                 The Thing       Amazon Prime Video          3.99
# 798                 The Thing                     Hulu  Subscription
#
# [799 rows x 3 columns]

# %%
Streaming_df_1.to_csv('Output/Google_Scraping_1.csv')

# %% [markdown]
# ### Scraped 164 movies so far
# ---

# %% [markdown]
# ### Scraping remaining movies

# %%
Streaming = []
Title = []
Price = []

count = 164

movies = google_query_url_df['Movie Title']

query_urls = google_query_url_df['Google Query URL']

base_url = 'https://www.google.com/search?&q='

# %%
for i in range(10):
    
    query_url = (f'{base_url}{movies[count]}+watch+movie')

    browser.visit(query_url)

    time.sleep(3)

    soup = BeautifulSoup(browser.html, 'lxml')

    results1 = soup.find_all('div', class_ = 'i3LlFf')

    for result in results1:
        try:
            Streaming.append(result.text)
            Title.append(movies[count].capitalize())
        except:
            Streaming.append('Nan')
            Title.append('Nan')

    results2 = soup.find_all('div', class_ = 'V8xno')

    for result in results2:
        try:
            Price.append(result.text)
        except:
            Price.append('Nan')
            
    count = count + 1

print(f'{Title}, {Streaming}, {Price}')
# Out:
# ['Gone with the wind', 'Gone with the wind', 'Gone with the wind', 'Gone with the wind', 'Gone with the wind', 'Room', 'Room', 'Room', 'Room', 'Room', 'Room', 'Jurassic park', 'Jurassic park', 'Jurassic park', 'Jurassic park', 'Wild strawberries', 'Wild strawberries', 'Blade runner', 'Blade runner', 'Blade runner', 'Blade runner', 'Blade runner', 'The bridge on the river kwai', 'The bridge on the river kwai', 'The bridge on the river kwai', 'The bridge on the river kwai', 'The bridge on the river kwai', 'Finding nemo', 'Finding nemo', 'Finding nemo', 'Finding nemo', 'Finding nemo', 'Finding nemo', 'Stalker', 'Stalker', 'Stalker', 'Stalker', 'Stalker', 'On the waterfront', 'On the waterfront', 'On the waterfront', 'On the waterfront', 'On the waterfront', 'The third man', 'The third man', 'The third man', 'The third man', 'The third man', 'The third man', 'Fargo', 'Fargo', 'Fargo', 'Fargo', 'Fargo', 'Fargo', 'Kill bill: vol', 'Kill bill: vol', 'Kill bill: vol', 'Kill bill: vol', 'Kill bill: vol', 'Kill bill: vol', 'The truman show', 'The truman show', 'The truman show', 'The truman show', 'The truman show', 'The truman show', 'Gran torino', 'Gran torino', 'Gran torino', 'Gran torino', 'Gran torino', 'Gran torino', 'Tokyo story', 'Tokyo story', 'Tokyo story', 'Tokyo story', 'Tokyo story', 'The deer hunter', 'The deer hunter', 'The deer hunter', 'The deer hunter', 'The deer hunter', 'Memories of murder', 'Relatos salvajes', 'Relatos salvajes', 'Relatos salvajes', 'Klaus', 'The bandit', 'The bandit', 'The bandit', 'The bandit', 'The bandit', 'The bandit', 'Andhadhun', 'Andhadhun', 'Andhadhun', 'Andhadhun', 'Mary and max', 'Mary and max', 'Mary and max', 'Mary and max', 'The big lebowski', 'The big lebowski', 'The big lebowski', 'The big lebowski', 'The big lebowski', 'The big lebowski', 'In the name of the father', 'In the name of the father', 'In the name of the father', 'In the name of the father', 'In the name of the father', 'Gone girl', 'Gone girl', 'Gone girl', 'Gone girl', 'Gone girl', 'Gone girl', 'Hacksaw ridge', 'Hacksaw ridge', 'Hacksaw ridge', 'Hacksaw ridge', 'Hacksaw ridge', 'The grand budapest hotel', 'The grand budapest hotel', 'The grand budapest hotel', 'The grand budapest hotel', 'The grand budapest hotel', 'To be or not to be', 'To be or not to be', 'To be or not to be', 'To be or not to be', 'To be or not to be', 'Ford v ferrari', 'Ford v ferrari', 'Ford v ferrari', 'Ford v ferrari', 'Persona', 'Persona', 'Before sunrise', 'Before sunrise', 'Before sunrise', 'Before sunrise', 'Before sunrise', 'Catch me if you can', 'Catch me if you can', 'Catch me if you can', 'Catch me if you can', 'Catch me if you can', 'How to train your dragon', 'How to train your dragon', 'How to train your dragon', 'How to train your dragon', 'How to train your dragon', 'How to train your dragon', 'The general', 'The general', 'The general', 'The general', 'The general', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Sherlock jr', 'Sherlock jr', 'Sherlock jr', 'Sherlock jr', 'Prisoners', 'Prisoners', 'Prisoners', 'Prisoners', 'Prisoners', 'Prisoners', '12 years a slave', '12 years a slave', '12 years a slave', '12 years a slave', '12 years a slave', 'Cool hand luke', 'Cool hand luke', 'Cool hand luke', 'Cool hand luke', 'Cool hand luke', 'Mad max: fury road', 'Mad max: fury road', 'Mad max: fury road', 'Mad max: fury road', 'Barry lyndon', 'Barry lyndon', 'Barry lyndon', 'Barry lyndon', 'Barry lyndon', 'Network', 'Network', 'Network', 'Network', 'Network', 'Network', 'The wages of fear', 'The wages of fear', 'Stand by me', 'Stand by me', 'Stand by me', 'Stand by me', 'Stand by me', 'Into the wild', 'Into the wild', 'Into the wild', 'Into the wild', 'Into the wild', 'Into the wild', 'Million dollar baby', 'Million dollar baby', 'Million dollar baby', 'Million dollar baby', 'Million dollar baby', "Monty python's life of brian", "Monty python's life of brian", "Monty python's life of brian", "Monty python's life of brian", "Monty python's life of br ...

# %%
print(f'Scraped {count} movies so far')
# Out:
# Scraped 214 movies so far

# %%
Streaming_df_2 = pd.DataFrame({'Title': Title,
                               'Streaming On' : Streaming,
                               'Price' : Price
                              })

Streaming_df_2['Price'] = Streaming_df_2['Price'].str.replace("$","", case = True, regex=True)
Streaming_df_2['Price'] = Streaming_df_2['Price'].str.replace("From ","", case = True, regex=True)
Streaming_df_2['Title'] = Streaming_df_2['Title'].str.title()

Streaming_df_2
# Out:
#                   Title             Streaming On Price
# 0    Gone With The Wind                  YouTube  3.99
# 1    Gone With The Wind                     Vudu  3.99
# 2    Gone With The Wind  Google Play Movies & TV  3.99
# 3    Gone With The Wind                   iTunes  3.99
# 4    Gone With The Wind       Amazon Prime Video  3.99
# ..                  ...                      ...   ...
# 236             Ben-Hur                  YouTube  3.99
# 237             Ben-Hur  Google Play Movies & TV  3.99
# 238             Ben-Hur                   iTunes  3.99
# 239             Ben-Hur                     Vudu  3.99
# 240             Ben-Hur       Amazon Prime Video  3.99
#
# [241 rows x 3 columns]

# %%
Streaming_df_2.to_csv('Output/Google_Scraping_2.csv')

# %% [markdown]
# ## Concatenating the two dataframes
# ---

# %%
Complete_Stremaing_df = pd.concat([Streaming_df_1, Streaming_df_2], ignore_index=True)
Complete_Stremaing_df
# Out:
#                          Title             Streaming On Price
# 0     The Shawshank Redemption                  YouTube  3.99
# 1     The Shawshank Redemption                   iTunes  3.99
# 2     The Shawshank Redemption  Google Play Movies & TV  3.99
# 3     The Shawshank Redemption                     Vudu  3.99
# 4     The Shawshank Redemption       Amazon Prime Video  3.99
# ...                        ...                      ...   ...
# 1035                   Ben-Hur                  YouTube  3.99
# 1036                   Ben-Hur  Google Play Movies & TV  3.99
# 1037                   Ben-Hur                   iTunes  3.99
# 1038                   Ben-Hur                     Vudu  3.99
# 1039                   Ben-Hur       Amazon Prime Video  3.99
#
# [1040 rows x 3 columns]

# %%
Complete_Stremaing_df.to_csv('Output/Complete_Google_Scraping.csv')

# %%
import os
os.getcwd()
# Out:
# '/Users/swarnaguntaka/Desktop/ETL-Project'
